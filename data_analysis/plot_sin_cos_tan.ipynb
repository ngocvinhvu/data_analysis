# %%
"""Vẽ đồ thị hàm sin,cos,tan trong khoảng -2𝜋 -> 2𝜋"""

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pi = np.pi
x = np.linspace(-2*pi, 2*pi, num=50)
plt.plot(x, np.sin(x))
plt.legend(['sin(x)'])

# %%
plt.plot(x, np.cos(x))
plt.legend(['cos(x)'])

# %%
plt.plot(x, np.tan(x))
plt.legend(['tan(x)'])
